# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Merged_Sunscreen Skinaqua.csv')
df.head(10)
# Out:
#           username           age           profile_description        date  \
# 0       dsekarayoe       19 - 24             Oily, Light, Cool  2024-11-16
# 1       AnisaFeb22       19 - 24          Normal, Medium, Warm  2024-10-29
# 2           reniwl       25 - 29             Dry, Medium, Warm  2024-10-27
# 3          kiyaacc  18 and Under  Combination, Medium, Neutral  2024-10-25
# 4         abiaraa_       19 - 24            Oily, Medium, Warm  2024-10-22
# 5         vivintya       25 - 29                      ,25 - 29  2024-09-28
# 6  chaerunnisamrwh       25 - 29  Combination, Medium, Neutral  2024-09-27
# 7     meimeithekid  18 and Under      Oily, Medium Light, Warm  2024-09-24
# 8              i30       35 - 39                      ,35 - 39  2024-09-21
# 9    lemonteaaaa12       19 - 24       Normal, Medium, Neutral  2024-09-18
#
#                                       review_content        usage_period  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   username             129 non-null    object
#  1   age                  129 non-null    object
#  2   profile_description  129 non-null    object
#  3   date                 129 non-null    object
#  4   review_content       129 non-null    object
#  5   usage_period         129 non-null    object
#  6   purchase_point       129 non-null    object
#  7   recommend            129 non-null    object
#  8   rating_count         129 non-null    int64
#  9   Jenis Produk         129 non-null    object
#  10  value                129 non-null    int64
# dtypes: int64(2), object(9)
# memory usage: 11.2+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# username               0
# age                    0
# profile_description    0
# date                   0
# review_content         0
# usage_period           0
# purchase_point         0
# recommend              0
# rating_count           0
# Jenis Produk           0
# value                  0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.describe())
# Out:
#        rating_count       value
# count    129.000000  129.000000
# mean       4.697674   48.542636
# std        0.691518   28.342770
# min        1.000000    0.000000
# 25%        5.000000   42.000000
# 50%        5.000000   55.000000
# 75%        5.000000   62.000000
# max        5.000000  100.000000

# %%
print(df['age'].unique())
# Out:
# ['19 - 24' '25 - 29' '18 and Under' '35 - 39' '30 - 34' '45 and Above']

# %%
# Define the mapping for age ranges to 4 categories
age_mapping = {
    '18 and Under': 'remaja',     # Teenagers
    '19 - 24': 'dewasa muda',    # Young adults
    '25 - 29': 'dewasa muda',
    '30 - 34': 'dewasa matang',  # Mature adults
    '35 - 39': 'dewasa matang',
    '40 - 44': 'dewasa matang',
    '45 and Above': 'paruh baya'        # Older adults
}

# Apply the mapping to the 'age' column
df['age_category'] = df['age'].map(age_mapping)

# Print unique values of the new 'age_category' column
print("Unique values in 'age_category':")
print(df['age_category'].unique())
# Out:
# Unique values in 'age_category':
# ['dewasa muda' 'remaja' 'dewasa matang' 'paruh baya']

# %%
print(df['profile_description'].unique())
# Out:
# ['Oily, Light, Cool' 'Normal, Medium, Warm' 'Dry, Medium, Warm'
#  'Combination, Medium, Neutral' 'Oily, Medium, Warm' ',25 - 29'
#  'Oily, Medium Light, Warm' ',35 - 39' 'Normal, Medium, Neutral'
#  'Combination, Medium Light, Neutral' 'Oily, Medium Light, Neutral'
#  'Combination, Medium Dark, Neutral' 'Oily, Medium, Neutral'
#  'Combination, Medium, Warm' 'Dry, Medium, Cool' 'Normal, Dark, Neutral'
#  'Normal, Medium Light, Neutral' 'Dry, Light, Warm'
#  'Oily, Medium Dark, Warm' ',19 - 24' 'Oily, Medium Light, Cool'
#  'Dry, Medium Light, Neutral' 'Combination, Light, Neutral'
#  'Normal, Light, Neutral' 'Combination, Medium Light, Cool'
#  'Combination, Medium Dark, Warm' 'Combination, Medium Dark, Cool'
#  'Oily, Light, Neutral' 'Dry, Medium, Neutral' 'Dry, Medium Dark, Warm'
#  'Dry, Light, Cool' 'Normal, Medium Dark, Neutral'
#  'Dry, Medium Light, Cool' 'Combination, Medium, Cool' ',30 - 34'
#  'Normal, Medium Light, Cool' 'Oily, Medium, Cool'
#  'Combination, Light, Cool']

# %%
# Rename the column 'profile_description' to 'skintype'
df.rename(columns={'profile_description': 'skintype'}, inplace=True)

# Check the unique values before filtering
print("Unique values in 'skintype' before filtering:")
print(df['skintype'].unique())

# Remove rows with specific unwanted values
unwanted_values = [',35 - 39', ',25 - 29', ',19 - 24', ',30 - 34' ]
df = df[~df['skintype'].isin(unwanted_values)]  # Keep rows not in the unwanted_values list

# Check the unique values after filtering
print("\nUnique values in 'skintype' after filtering:")
print(df['skintype'].unique())
# Out:
# Unique values in 'skintype' before filtering:
# ['Oily, Light, Cool' 'Normal, Medium, Warm' 'Dry, Medium, Warm'
#  'Combination, Medium, Neutral' 'Oily, Medium, Warm' ',25 - 29'
#  'Oily, Medium Light, Warm' ',35 - 39' 'Normal, Medium, Neutral'
#  'Combination, Medium Light, Neutral' 'Oily, Medium Light, Neutral'
#  'Combination, Medium Dark, Neutral' 'Oily, Medium, Neutral'
#  'Combination, Medium, Warm' 'Dry, Medium, Cool' 'Normal, Dark, Neutral'
#  'Normal, Medium Light, Neutral' 'Dry, Light, Warm'
#  'Oily, Medium Dark, Warm' ',19 - 24' 'Oily, Medium Light, Cool'
#  'Dry, Medium Light, Neutral' 'Combination, Light, Neutral'
#  'Normal, Light, Neutral' 'Combination, Medium Light, Cool'
#  'Combination, Medium Dark, Warm' 'Combination, Medium Dark, Cool'
#  'Oily, Light, Neutral' 'Dry, Medium, Neutral' 'Dry, Medium Dark, Warm'
#  'Dry, Light, Cool' 'Normal, Medium Dark, Neutral'
#  'Dry, Medium Light, Cool' 'Combination, Medium, Cool' ',30 - 34'
# ...

# %%
print(df['usage_period'].unique())
print(df['rating_count'].unique())
print(df['Jenis Produk'].unique())
# Out:
# ['6 months - 1 year' 'More than 1 year' '1 month - 3 months'
#  '1 week - 1 month' '3 months - 6 months' 'Less than 1 week']
# [5 4 3 1 2]
# ['Skinaqua UV Moisture Gel' 'Skinaqua UV Moisture Milk'
#  'Skinaqua UV Whitening Milk']

# %%
# Mapping periode penggunaan ke dalam tiga kategori dalam bahasa Indonesia
usage_period_mapping_id = {
    'Less than 1 week': 'Jangka Pendek',
    '1 week - 1 month': 'Jangka Pendek',
    '1 month - 3 months': 'Jangka Pendek',
    '3 months - 6 months': 'Jangka Menengah',
    '6 months - 1 year': 'Jangka Menengah',
    'More than 1 year': 'Jangka Panjang'
}

# Terapkan mapping pada kolom 'usage_period'
df['periode_penggunaan'] = df['usage_period'].map(usage_period_mapping_id)

# Cetak nilai unik dari kolom baru
print("Nilai unik dalam 'periode_penggunaan':")
print(df['periode_penggunaan'].unique())
# Out:
# Nilai unik dalam 'periode_penggunaan':
# ['Jangka Menengah' 'Jangka Panjang' 'Jangka Pendek']
# <ipython-input-31-e8a79d42d6ac>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['periode_penggunaan'] = df['usage_period'].map(usage_period_mapping_id)

# %%
#rename column
df.rename(columns={'rating_count': 'rating'}, inplace=True)
print(df['rating'].unique())
df.rename(columns={'Jenis Produk': 'Jenis_Produk'}, inplace=True)
print(df['Jenis_Produk'].unique())
df.rename(columns={'value': 'trend'}, inplace=True)
print(df['trend'].unique())
# Out:
# [5 4 3 1 2]
# ['Skinaqua UV Moisture Gel' 'Skinaqua UV Moisture Milk'
#  'Skinaqua UV Whitening Milk']
# [ 46   0 100  59  60  50  42  78  47  41  39  48  64  72  44  62  65  54
#   58  61  53  85  73  51  76  45  69  63  33  55  87]
# <ipython-input-32-73f6ff84d89d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'rating_count': 'rating'}, inplace=True)
# <ipython-input-32-73f6ff84d89d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Jenis Produk': 'Jenis_Produk'}, inplace=True)
# <ipython-input-32-73f6ff84d89d>:6: SettingWithCopyWarning:
# ...

# %%
df.drop(columns=['usage_period'], inplace=True)
df.drop(columns=['age'], inplace=True)
df.head(10)
# Out:
# <ipython-input-33-f0901c1c06af>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['usage_period'], inplace=True)
# <ipython-input-33-f0901c1c06af>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['age'], inplace=True)
#            username                            skintype        date  \
# 0        dsekarayoe                   Oily, Light, Cool  2024-11-16
# 1        AnisaFeb22                Normal, Medium, Warm  2024-10-29
# 2            reniwl                   Dry, Medium, Warm  2024-10-27
# 3           kiyaacc        Combination, Medium, Neutral  2024-10-25
# ...

# %%
# Mapping nilai dalam kolom 'recommend' menjadi kategori 'recommend' dan 'not recommend'
df['Recommend'] = df['recommend'].apply(
    lambda x: 'recommend' if 'recommends this product!' in str(x).lower() else 'not recommend'
)

# Tampilkan nilai unik dalam kolom baru
print(df['Recommend'].unique())
drop = ['recommend']
df.drop(columns=drop, inplace=True)
df.head(10)
# Out:
# ['recommend' 'not recommend']
# <ipython-input-34-4b2a743f4c41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Recommend'] = df['recommend'].apply(
# <ipython-input-34-4b2a743f4c41>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=drop, inplace=True)
#            username                            skintype        date  \
# 0        dsekarayoe                   Oily, Light, Cool  2024-11-16
# 1        AnisaFeb22                Normal, Medium, Warm  2024-10-29
# ...

# %%
# Memisahkan kolom 'skintype' menjadi beberapa bagian berdasarkan koma
df[['skintype', 'skintone', 'undertone']] = df['skintype'].str.split(',', expand=True)

# Membersihkan nilai yang dihasilkan (menghapus spasi tambahan)
df['skintype'] = df['skintype'].str.strip()
df['skintone'] = df['skintone'].str.strip()
df['undertone'] = df['undertone'].str.strip()

# Tampilkan beberapa baris pertama untuk memverifikasi hasil
print(df[['skintype', 'skintone', 'undertone']].head())
# Out:
#       skintype skintone undertone
# 0         Oily    Light      Cool
# 1       Normal   Medium      Warm
# 2          Dry   Medium      Warm
# 3  Combination   Medium   Neutral
# 4         Oily   Medium      Warm
# <ipython-input-35-7d41ab592ce1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['skintype', 'skintone', 'undertone']] = df['skintype'].str.split(',', expand=True)
# <ipython-input-35-7d41ab592ce1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head(10)
# Out:
#            username     skintype        date  \
# 0        dsekarayoe         Oily  2024-11-16
# 1        AnisaFeb22       Normal  2024-10-29
# 2            reniwl          Dry  2024-10-27
# 3           kiyaacc  Combination  2024-10-25
# 4          abiaraa_         Oily  2024-10-22
# 6   chaerunnisamrwh  Combination  2024-09-27
# 7      meimeithekid         Oily  2024-09-24
# 9     lemonteaaaa12       Normal  2024-09-18
# 10          Hrsheli  Combination  2024-08-24
# 11      Adryanfahmi  Combination  2024-11-17
#
#                                        review_content purchase_point  rating  \
# 0   Aku biasa pake sunscreen ini buat dirumah aja ...         Shopee       5
# 1   Sunscreen yang paling sering aku repurchase it...       Guardian       5
# 2   Suka sekali sama varian yang ini. Padahal untu...         Shopee       5
# 3   Sukaa bangett sama tekstur sunscreennyaaa!!! c...       Guardian       5
# 4   teksturnya kaya lotion, putih pekat tp begitu ...         Shopee       5
# ...

# %%
# Sorting berdasarkan kolom 'Jenis_Produk'
df_sorted = df.sort_values(by='Jenis_Produk', ascending=True)

# Tampilkan data yang sudah diurutkan
print(df_sorted.head(10))  # Menampilkan beberapa baris pertama
# Out:
#            username     skintype        date  \
# 0        dsekarayoe         Oily  2024-11-16
# 1        AnisaFeb22       Normal  2024-10-29
# 2            reniwl          Dry  2024-10-27
# 3           kiyaacc  Combination  2024-10-25
# 4          abiaraa_         Oily  2024-10-22
# 6   chaerunnisamrwh  Combination  2024-09-27
# 7      meimeithekid         Oily  2024-09-24
# 9     lemonteaaaa12       Normal  2024-09-18
# 10          Hrsheli  Combination  2024-08-24
# 49         dvinagfk       Normal  2024-09-21
#
#                                        review_content purchase_point  rating  \
# 0   Aku biasa pake sunscreen ini buat dirumah aja ...         Shopee       5
# 1   Sunscreen yang paling sering aku repurchase it...       Guardian       5
# 2   Suka sekali sama varian yang ini. Padahal untu...         Shopee       5
# 3   Sukaa bangett sama tekstur sunscreennyaaa!!! c...       Guardian       5
# 4   teksturnya kaya lotion, putih pekat tp begitu ...         Shopee       5
# ...

# %%
# Simpan df_sorted ke dalam file CSV
df_sorted.to_csv('sorted_data skinaqua.csv', index=False)

# Simpan df_sorted ke dalam file Excel
df_sorted.to_excel('sorted_data skinaqua.xlsx', index=False)

print("Data telah disimpan ke 'sorted_data.csv' dan 'sorted_data.xlsx'")
# Out:
# Data telah disimpan ke 'sorted_data.csv' dan 'sorted_data.xlsx'
