# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sorted_data.csv')
df.head(10)
# Out:
#         username     skintype        date  \
# 0        rahelch  Combination  2024-11-15
# 1       thiis_10          Dry  2024-09-26
# 2        almiraa  Combination  2024-09-26
# 3      diyandita         Oily  2024-09-25
# 4        hann_ad          Dry  2024-09-25
# 5    starbroocks         Oily  2024-09-24
# 6      alicslwa_         Oily  2024-09-23
# 7       zakiatr_         Oily  2024-09-23
# 8  kholifahtur81  Combination  2024-09-21
# 9        PattD59          Dry  2024-09-18
#
#                                       review_content  \
# 0  Hidden gem? Wkwkwk Akhirnya menemukan ss yang ...
# 1  Cocok buat pemula yang baru terjun ke dunia sk...
# 2  satu satunya sunscreen yang cocok banget dan g...
# 3  Jujur, ini salah satu SS legend menurut aku, d...
# 4  Tidak menimbulkan jerawat selamat pemakaian.. ...
# 5  Sunscreen tercocok, terbagus, ter affordable, ...
# 6  Aku suka banget sama sunscreen ini. Apalagi bu...
# 7  Pernah pake sekali karena ditempatku yang vari...
# ...

# %%
df['Recommend'] = df['Recommend'].map({'recommend': 1, 'not recommend': 0})

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Pilih kolom numerik saja untuk korelasi
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = df[numerical_cols].corr()

# Visualisasi correlation matrix dengan heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Calm My Acne Sunscreen Moisturizer']

# Pastikan kolom 'rating' tersedia di filtered_df
if 'rating' not in filtered_df.columns:
    print("Kolom 'rating' tidak ditemukan dalam dataset.")
else:
    # Plot distribusi rating
    plt.figure(figsize=(8, 6))
    sns.countplot(data=filtered_df, x='rating', palette='viridis')
    plt.title('Distribusi Rating untuk Azarine Calm My Acne Sunscreen Moisturizer', fontsize=14)
    plt.xlabel('Rating', fontsize=12)
    plt.ylabel('Jumlah', fontsize=12)
    plt.show()
# Out:
# <ipython-input-25-262ff0d6b73b>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_df, x='rating', palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Hydramax C Sunscreen Serum']

# Plot distribusi rating
plt.figure(figsize=(8, 6))
sns.countplot(data=filtered_df, x='rating', palette='viridis')
plt.title('Distribusi Rating untuk Azarine Hydramax C Sunscreen Serum', fontsize=14)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.show()
# Out:
# <ipython-input-19-8bf0878682ea>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_df, x='rating', palette='viridis')

# %%
# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Hydrashoote Sunscreen Gel']

# Plot distribusi rating
plt.figure(figsize=(8, 6))
sns.countplot(data=filtered_df, x='rating', palette='viridis')
plt.title('Distribusi Rating untuk Azarine Hydrashoote Sunscreen Gel', fontsize=14)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.show()
# Out:
# <ipython-input-20-80e78d1fc8e9>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_df, x='rating', palette='viridis')

# %%
# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Calm My Acne Sunscreen Moisturizer']

# Plot distribusi rating
plt.figure(figsize=(8, 6))
sns.countplot(data=filtered_df, x='rating', palette='viridis')
plt.title('Distribusi Rating untuk Azarine Calm My Acne Sunscreen Moisturizer', fontsize=14)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.show()
# Out:
# <ipython-input-21-d30d66bcef7d>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_df, x='rating', palette='viridis')

# %%
# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Hydramax C Sunscreen Serum']

# Plot distribusi rating
plt.figure(figsize=(8, 6))
sns.countplot(data=filtered_df, x='rating', palette='viridis')
plt.title('Distribusi Rating untuk Azarine Hydramax C Sunscreen Serum', fontsize=14)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.show()
# Out:
# <ipython-input-26-4fa133608276>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_df, x='rating', palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Calm My Acne Sunscreen Moisturizer']

# Membuat plot berdasarkan age_category
plt.figure(figsize=(8, 6))
sns.countplot(
    data=filtered_df,
    x='age_category',
    palette='viridis'
)
plt.title('Distribusi Berdasarkan Age Category untuk Azarine Calm My Acne Sunscreen Moisturizer', fontsize=14)
plt.xlabel('Kategori Usia (Age Category)', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-c42856ff5678>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filter data untuk produk Skinaqua UV Moisture Gel
filter_df = df[df['Jenis_Produk'] == 'Azarine Hydramax C Sunscreen Serum']

# Membuat plot berdasarkan age_category
plt.figure(figsize=(8, 6))
sns.countplot(
    data=filter_df,
    x='age_category',
    palette='viridis'
)
plt.title('Distribusi Berdasarkan Age Category untuk Azarine Hydramax C Sunscreen Serum', fontsize=14)
plt.xlabel('Kategori Usia (Age Category)', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-6017c09084fa>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Hydrashoote Sunscreen Gel']

# Membuat plot berdasarkan age_category
plt.figure(figsize=(8, 6))
sns.countplot(
    data=filtered_df,
    x='age_category',
    palette='viridis'
)
plt.title('Distribusi Berdasarkan Age Category untuk Azarine Hydrashoote Sunscreen Gel', fontsize=14)
plt.xlabel('Kategori Usia (Age Category)', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-29-4c3eba7602ba>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Calm My Acne Sunscreen Moisturizer']

# Membuat plot berdasarkan periode_penggunaan
plt.figure(figsize=(8, 6))
sns.countplot(
    data=filtered_df,
    x='periode_penggunaan',
    palette='viridis'
)
plt.title('Distribusi Berdasarkan Periode Penggunaan untuk Azarine Calm My Acne Sunscreen Moisturizer', fontsize=14)
plt.xlabel('Periode Penggunaan', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-bcd99f101dbd>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Hydramax C Sunscreen Serum']

# Membuat plot berdasarkan periode_penggunaan
plt.figure(figsize=(8, 6))
sns.countplot(
    data=filtered_df,
    x='periode_penggunaan',
    palette='viridis'
)
plt.title('Distribusi Berdasarkan Periode Penggunaan untuk Azarine Hydramax C Sunscreen Serum', fontsize=14)
plt.xlabel('Periode Penggunaan', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-28-8877a77118a3>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Filter data untuk produk Skinaqua UV Moisture Gel
filtered_df = df[df['Jenis_Produk'] == 'Azarine Hydrashoote Sunscreen Gel']

# Membuat plot berdasarkan periode_penggunaan
plt.figure(figsize=(8, 6))
sns.countplot(
    data=filtered_df,
    x='periode_penggunaan',
    palette='viridis'
)
plt.title('Distribusi Berdasarkan Periode Penggunaan untuk Azarine Hydrashoote Sunscreen Gel', fontsize=14)
plt.xlabel('Periode Penggunaan', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-30-b9b6b0e23eed>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filter data untuk periode_penggunaan = "Jangka Panjang"
filtered_df = df[df['periode_penggunaan'] == 'Jangka Panjang']

# Membuat plot perbandingan berdasarkan jenis produk
plt.figure(figsize=(10, 6))
sns.countplot(
    data=filtered_df,
    x='Jenis_Produk',
    palette='viridis'
)
plt.title('Distribusi Jenis Produk dengan Periode Penggunaan Jangka Panjang', fontsize=14)
plt.xlabel('Jenis Produk', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-70a12cff3828>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Menghitung jumlah pengguna untuk setiap Jenis_Produk
product_counts = df['Jenis_Produk'].value_counts()

# Warna khusus: pink, ungu, dan biru
colors = ['#FFC0CB', '#9370DB', '#87CEEB']  # Pink, ungu, biru

# Membuat pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    product_counts,
    labels=product_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors
)
plt.title('Distribusi Pengguna Berdasarkan Jenis Produk', fontsize=14)
plt.axis('equal')  # Membuat pie chart berbentuk lingkaran sempurna
plt.tight_layout()
plt.show()
